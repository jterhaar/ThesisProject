# %%
import xarray as xr

ds = xr.open_dataset("/nobackup/users/haar/radar_data/MFBS/6H20-23-preprocessed/2020/01/RAD_NL25_RAC_MFBS_06H_202001040600.nc")

print(ds.longitude.values.min(), ds.longitude.values.max())
print(ds.latitude.values.min(), ds.latitude.values.max())
# Out:
# 0.0 10.855999946594238
# 48.89500045776367 55.9739990234375
